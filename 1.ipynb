# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
df=sns.load_dataset('taxis')

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.describe(include='object')
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6341         6341            6341                   6341
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5373         4546             227                    244
#
#        pickup_borough dropoff_borough
# count            6341            6341
# unique              4               5
# top         Manhattan       Manhattan
# freq             5226            5172

# %%
df.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100
# percentage of data lost
# Out:
# 1.4301259132597544

# %%
df=df.dropna()

# %%
df.reset_index(drop=True)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6336 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6337 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6338 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6339 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6340 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.shape
# Out:
# (6341, 14)

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6341                           6341
# mean   2019-03-16 08:30:26.574830080  2019-03-16 08:44:47.525784832
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:28:20            2019-03-08 15:54:00
# 50%              2019-03-15 21:57:47            2019-03-15 22:07:48
# 75%              2019-03-23 17:45:29            2019-03-23 17:57:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare          tip        tolls  \
# count  6341.000000  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931     1.972703     0.314793
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# ...

# %%
df.describe(include='object')
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6341         6341            6341                   6341
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5373         4546             227                    244
#
#        pickup_borough dropoff_borough
# count            6341            6341
# unique              4               5
# top         Manhattan       Manhattan
# freq             5226            5172

# %% [markdown]
# EDA

# %%
#tip is the target column
#tip is the numerical column ,analyze with color which is categorical

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
#there are 2 unique categories
#graphical analysis of categorical
sns.barplot(x=df.color,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sns.barplot(x=df.color,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
sns.histplot(x=df.tip,hue=df.color,kde=True,palette=['yellow','green'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# GRAPH INSIGHTS
#
# Most tip values are small, and only a few are high.
#
# Both color groups follow almost the same pattern.
#
# One color appears slightly more frequent, but the difference is not big.
#
# The tips for both groups are mostly concentrated in the same range.
#
# Very high tip values are rare for both colors.

# %% [markdown]
# **Hypotheses:**
# - H0: distribution of tip for yellow = distribution of tip for green
# - H1: distribution of tip for yellow ≠ distribution of tip for green

# %%
yellow_tip=df['tip'][df['color']=='yellow']
green_tip=df['tip'][df['color']=='green']

# %%
yellow_tip.shape
# Out:
# (5373,)

# %%
green_tip.shape
# Out:
# (968,)

# %%
# Independent T-Test

from scipy import stats
t_stat, p_val = stats.ttest_ind(yellow_tip, green_tip)
#print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
# Out:
# P-value: 7.791088119489453e-64

# %%
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis:The tip for yellow category is different from that of green")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis:The tip for yellow category is different from that of green

# %%
#There is an effect of color on tip column

# %%
sns.barplot(x=df.payment,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.barplot(x=df.payment,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
import matplotlib.pyplot as plt
sns.histplot(x=df.tip,hue=df.color,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df['payment']
# Out:
# 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6341, dtype: object

# %%
cash_payment=df['tip'][df['payment']=='cash']
card_payment=df['tip'][df['payment']=='credit card']

# %% [markdown]
# **Hypotheses:**
# - H0: distribution of tip through cash = distribution of tip through credit card
# - H1: distribution of tip  through cash ≠ distribution of tip through credit card

# %%
# Independent T-Test

from scipy import stats
t_stat, p_val = stats.ttest_ind(cash_payment, card_payment)
#print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
# Out:
# P-value: 0.0

# %%
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis:The tip for payment through card is different from that of cash")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis:The tip for payment through card is different from that of cash

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'], dtype=object)

# %%
sns.countplot(x=df['pickup_borough'],palette='Set1')
# Out:
# C:\Users\ashri\AppData\Local\Temp\ipykernel_23888\953540929.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['pickup_borough'],palette='Set1')
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %%
sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# Out:
# C:\Users\ashri\AppData\Local\Temp\ipykernel_23888\2462997792.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.979127
# Manhattan    1.945597
# Queens       3.066458
# Name: tip, dtype: float64

# %%
df['tip'].groupby(df['pickup_borough']).std()
# Out:
# pickup_borough
# Bronx        0.897261
# Brooklyn     1.674487
# Manhattan    1.997736
# Queens       4.323951
# Name: tip, dtype: float64

# %% [markdown]
# **Hypothesis**
#
# H0: distribution of tip is the same across all pickup_borough categories
#
# H1: Atleat one category has a different distribution of tip

# %%
manhatten_tip=df['tip'][df['pickup_borough']=='Manhattan']
bronx_tip=df['tip'][df['pickup_borough']=='Bronx']
brooklyn_tip=df['tip'][df['pickup_borough']=='Brooklyn']
queens_tip=df['tip'][df['pickup_borough']=='Queens']
staten_tip=df['tip'][df['pickup_borough']=='Staten ']

# %%
#ANOVA test

from scipy import stats
t_stat, p_val = stats.f_oneway(manhatten_tip,bronx_tip,brooklyn_tip,queens_tip)

print("P-value:", p_val)
# Out:
# P-value: 5.155109332424193e-58

# %%
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis

# %%
sns.countplot(x=df['dropoff_borough'],palette='Set1')
# Out:
# C:\Users\ashri\AppData\Local\Temp\ipykernel_23888\527273607.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['dropoff_borough'],palette='Set1')
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %%
sns.barplot(x=df['dropoff_borough'],y=df['tip'],palette='Set2')
# Out:
# C:\Users\ashri\AppData\Local\Temp\ipykernel_23888\2768024598.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'],y=df['tip'],palette='Set2')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['dropoff_borough']).std()
# Out:
# dropoff_borough
# Bronx            1.788795
# Brooklyn         2.896229
# Manhattan        2.052074
# Queens           3.947016
# Staten Island    2.976920
# Name: tip, dtype: float64

# %%
df['tip'].groupby(df['dropoff_borough']).mean()
# Out:
# dropoff_borough
# Bronx             0.534706
# Brooklyn          1.921590
# Manhattan         1.964321
# Queens            2.422022
# Staten Island    14.165000
# Name: tip, dtype: float64

# %%
manhatten_tip=df['tip'][df['dropoff_borough']=='Manhattan']
bronx_tip=df['tip'][df['dropoff_borough']=='Bronx']
brooklyn_tip=df['tip'][df['dropoff_borough']=='Brooklyn']
queens_tip=df['tip'][df['dropoff_borough']=='Queens']
staten_tip=df['tip'][df['dropoff_borough']=='Staten ']

# %%
#ANOVA test

from scipy import stats
t_stat, p_val = stats.f_oneway(manhatten_tip,bronx_tip,brooklyn_tip,queens_tip)

print("P-value:", p_val)
# Out:
# P-value: 2.637820690210475e-15

# %%
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis

# %%
# from statsmodels.stats.multicomp import pairwise_tukeyhsd
# tukey_result=pairwise_tukeyhsd(endog=df.tip ,groups=df.pickup,alpha=0.05)
# print(tukey_result)

# %%
sns.countplot(x=df['dropoff_zone'])
plt.show()

# %%
categories=[group['tip'].values for name,group in df.groupby('pickup_zone')]

f_stat,p_val=stats.f_oneway(*categories)
print("p-val",p_val)
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# p-val 7.892434822136223e-169
# Reject null hypothesis

# %%
#ANOVA TEST
categories=[group['tip'].values for name,group in df.groupby('dropoff_zone')]

f_stat,p_val=stats.f_oneway(*categories)
print("p-val",p_val)
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# p-val 1.3107168403745948e-120
# Reject null hypothesis

# %% [markdown]
# **HYPOTHESIS**
#
# H0: correlation is zero
# H1 : there is significant correlation (not zero)

# %%
r,p_val=stats.spearmanr(df['tip'],df['passengers'])
print("correlation :",r)
print("p-value:",p_val)
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis.There is no relationship")
else:
    print("Fail to reject null hypothesis.There is a relationship")
# Out:
# correlation : 0.027509812818779178
# p-value: 0.028480753176042872
# Reject null hypothesis.There is no relationship

# %%
sns.barplot(x=df.passengers,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='passengers', ylabel='tip'>

# %%
df['fare'].skew()
# Out:
# np.float64(2.606558389580325)

# %%
r,p_val=stats.spearmanr(df['tip'],df['fare'])
print("correlation :",r)
print("p-value:",p_val)
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis.There is no relationship")
else:
    print("Fail to reject null hypothesis.There is a relationship")
# Out:
# correlation : 0.310254279563729
# p-value: 1.5556730728881364e-141
# Reject null hypothesis.There is no relationship

# %%
sns.scatterplot(x=df.tip,y=df.fare)
# Out:
# <Axes: xlabel='tip', ylabel='fare'>

# %%
sns.histplot(df.fare,kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
r,p_val=stats.spearmanr(df['tip'],df['distance'])
print("correlation :",r)
print("p-value:",p_val)
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis.There is no relationship")
else:
    print("Fail to reject null hypothesis.There is a relationship")
# Out:
# correlation : 0.29265085410043695
# p-value: 1.9411181331374707e-125
# Reject null hypothesis.There is no relationship

# %%
df['distance'].skew()
# Out:
# np.float64(2.8870233381954415)

# %%
sns.scatterplot(x=df.tip,y=df.distance)
# Out:
# <Axes: xlabel='tip', ylabel='distance'>

# %%
sns.scatterplot(x=df.tip,y=df.total)
# Out:
# <Axes: xlabel='tip', ylabel='total'>

# %%
df['passengers'].skew()
# Out:
# np.float64(2.349366327837006)

# %%
r,p_val=stats.spearmanr(df['tip'],df['passengers'])
print("correlation :",r)
print("p-value:",p_val)
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis.There is no relationship")
else:
    print("Fail to reject null hypothesis.There is a relationship")
# Out:
# correlation : 0.027509812818779178
# p-value: 0.028480753176042872
# Reject null hypothesis.There is no relationship

# %%
sns.scatterplot(x=df.tip,y=df.passengers)
plt.show()

# %%
df['total'].skew()
# Out:
# np.float64(2.635965898086771)

# %%
r,p_val=stats.spearmanr(df['tip'],df['total'])
print("correlation :",r)
print("p-value:",p_val)
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis.There is no relationship")
else:
    print("Fail to reject null hypothesis.There is a relationship")
# Out:
# correlation : 0.5028299699182296
# p-value: 0.0
# Reject null hypothesis.There is no relationship

# %%
sns.scatterplot(x=df.tip,y=df.tolls)
# Out:
# <Axes: xlabel='tip', ylabel='tolls'>

# %%
df['tolls'].skew()
# Out:
# np.float64(4.876125068610457)

# %%
r,p_val=stats.spearmanr(df['tip'],df['tolls'])
print("correlation :",r)
print("p-value:",p_val)
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis.There is no relationship")
else:
    print("Fail to reject null hypothesis.There is a relationship")
# Out:
# correlation : 0.175380002891528
# p-value: 5.643276180955435e-45
# Reject null hypothesis.There is no relationship

# %%
nm=df[['fare','tip','tolls','distance','passengers']]

# %%
sns.heatmap(nm.corr(),annot=True,cmap="Blues")
plt.show()

# %%
sns.histplot(x=df.tip,hue=df.passengers,kde=True)
plt.show()

# %%
sns.barplot(x=df.fare,y=df.tip,estimator='mean')
plt.show()

# %% [markdown]
# **ANALYSIS OF DATE TIME COLUMNS**

# %%
df['pickup']
# Out:
# 0      2019-03-23 20:21:09
# 1      2019-03-04 16:11:55
# 2      2019-03-27 17:53:01
# 3      2019-03-10 01:23:59
# 4      2019-03-30 13:27:42
#                ...
# 6428   2019-03-31 09:51:53
# 6429   2019-03-31 17:38:00
# 6430   2019-03-23 22:55:18
# 6431   2019-03-04 10:09:25
# 6432   2019-03-13 19:31:22
# Name: pickup, Length: 6341, dtype: datetime64[ns]

# %%
df['pickup'].dt.day  #extract only date
# Out:
# 0       23
# 1        4
# 2       27
# 3       10
# 4       30
#         ..
# 6428    31
# 6429    31
# 6430    23
# 6431     4
# 6432    13
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 6428    3
# 6429    3
# 6430    3
# 6431    3
# 6432    3
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.month_name()   #extract month name
# Out:
# 0       March
# 1       March
# 2       March
# 3       March
# 4       March
#         ...
# 6428    March
# 6429    March
# 6430    March
# 6431    March
# 6432    March
# Name: pickup, Length: 6341, dtype: object

# %%
df['pickup'].dt.year
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 6428    2019
# 6429    2019
# 6430    2019
# 6431    2019
# 6432    2019
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.quarter  #quarter of the year
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6428    1
# 6429    1
# 6430    1
# 6431    1
# 6432    1
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.day_name()
# Out:
# 0        Saturday
# 1          Monday
# 2       Wednesday
# 3          Sunday
# 4        Saturday
#           ...
# 6428       Sunday
# 6429       Sunday
# 6430     Saturday
# 6431       Monday
# 6432    Wednesday
# Name: pickup, Length: 6341, dtype: object

# %%
df['pickup'].dt.weekday
# Out:
# 0       5
# 1       0
# 2       2
# 3       6
# 4       5
#        ..
# 6428    6
# 6429    6
# 6430    5
# 6431    0
# 6432    2
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.minute
# Out:
# 0       21
# 1       11
# 2       53
# 3       23
# 4       27
#         ..
# 6428    51
# 6429    38
# 6430    55
# 6431     9
# 6432    31
# Name: pickup, Length: 6341, dtype: int32

# %%
len(df['pickup'].unique())
# Out:
# 6322

# %%
df['pickup_month']=df['pickup'].dt.month_name() #adding new column pickup_month

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough pickup_month  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan        March
# ...

# %%
df['pickup_year']=df['pickup'].dt.year

# %%
df['pickup_dayname']=df['pickup'].dt.day_name()
df['pickup_hour']=df['pickup'].dt.hour
df['pickup_day']=df['pickup'].dt.day

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough pickup_month  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan        March
# ...

# %%
df.pickup_month.value_counts()
# Out:
# pickup_month
# March       6340
# February       1
# Name: count, dtype: int64

# %%
df['dropoff_month']=df['dropoff'].dt.month_name()
df['dropoff_year']=df['dropoff'].dt.year
df['dropoff_dayname']=df['dropoff'].dt.day_name()
df['dropoff_hour']=df['dropoff'].dt.hour
df['dropoff_minute']=df['dropoff'].dt.minute
df['dropoff_second']=df['dropoff'].dt.second
df['dropoff_quarter']=df['dropoff'].dt.quarter
df['dropoff_day']=df['dropoff'].dt.day

# %%
df.dropoff_month.value_counts()
# Out:
# dropoff_month
# March       6339
# April          1
# February       1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment  ... pickup_hour pickup_day  \
# 0    0.0  12.95  yellow  credit card  ...          20         23
# 1    0.0   9.30  yellow         cash  ...          16          4
# 2    0.0  14.16  yellow  credit card  ...          17         27
# 3    0.0  36.95  yellow  credit card  ...           1         10
# 4    0.0  13.40  yellow  credit card  ...          13         30
#
#   dropoff_month dropoff_year dropoff_dayname  dropoff_hour dropoff_minute  \
# ...

# %%
df.shape
# Out:
# (6341, 27)

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough', 'pickup_month', 'pickup_year',
#        'pickup_dayname', 'pickup_hour', 'pickup_day', 'dropoff_month',
#        'dropoff_year', 'dropoff_dayname', 'dropoff_hour', 'dropoff_minute',
#        'dropoff_second', 'dropoff_quarter', 'dropoff_day'],
#       dtype='object')

# %% [markdown]
# **HYPOTHESIS**
#
# H₀: Fare has no association with tip
#
# H₁: Fare has a significant association with tip

# %%
from scipy.stats import spearmanr

r,p_val= spearmanr(df['fare'], df['tip'])
print("correlation :",r)
print("p-value:",p_val)
alpha=0.05 #significance label
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# correlation : 0.310254279563729
# p-value: 1.5556730728881364e-141
# Reject null hypothesis

# %%
from scipy.stats import ttest_ind

weekday = df[df['pickup_dayname'].isin(['Monday','Tuesday','Wednesday','Thursday','Friday'])]['tip']
weekend = df[df['pickup_dayname'].isin(['Saturday','Sunday'])]['tip']

stat, p = ttest_ind(weekday, weekend, equal_var=False)
print(p)
alpha=0.05 #significance label
if p< alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# 0.009626082855043117
# Reject null hypothesis

# %%
groups = [g['tip'].values for _, g in df.groupby('pickup_hour')]
stat, p = f_oneway(*groups)
print(p)
alpha=0.05 #significance label
if p< alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# 0.02124589598191853
# Reject null hypothesis

# %%
groups = [g['tip'].values for _, g in df.groupby('pickup_month')]
stat, p = f_oneway(*groups)
print(p)
alpha=0.05 #significance label
if p< alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# 0.4035995080175966
# Fail to reject null hypothesis

# %%
groups = [g['tip'].values for _, g in df.groupby('pickup_day')]
stat, p = f_oneway(*groups)
print(p)
alpha=0.05 #significance label
if p< alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# 0.26170906759007273
# Fail to reject null hypothesis

# %%
groups = [g['tip'].values for _, g in df.groupby('dropoff_day')]
stat, p = f_oneway(*groups)
print(p)
alpha=0.05 #significance label
if p< alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# 0.16237110545718186
# Fail to reject null hypothesis

# %%
groups = [g['tip'].values for _, g in df.groupby('dropoff_minute')]
stat, p = f_oneway(*groups)
print(p)
alpha=0.05 #significance label
if p< alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# 0.13819958833054127
# Fail to reject null hypothesis

# %%
groups = [g['tip'].values for _, g in df.groupby('dropoff_second')]
stat, p = f_oneway(*groups)
print(p)
alpha=0.05 #significance label
if p< alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# 0.9777168475575204
# Fail to reject null hypothesis

# %%
groups = [g['tip'].values for _, g in df.groupby('dropoff_quarter')]
stat, p = f_oneway(*groups)
print(p)
alpha=0.05 #significance label
if p< alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# 0.4035995080175966
# Fail to reject null hypothesis

# %%
drop_list=['pickup','dropoff','pickup_month','pickup_day','pickup_year','dropoff_day','dropoff_month','dropoff_year','dropoff_minute','dropoff_second','dropoff_quarter']

# %%
df.drop(columns=drop_list, errors='ignore', inplace=True)

# %%
df.head()
# Out:
#    passengers  distance  fare   tip  tolls  total   color      payment  \
# 0           1      1.60   7.0  2.15    0.0  12.95  yellow  credit card
# 1           1      0.79   5.0  0.00    0.0   9.30  yellow         cash
# 2           1      1.37   7.5  2.36    0.0  14.16  yellow  credit card
# 3           1      7.70  27.0  6.15    0.0  36.95  yellow  credit card
# 4           3      2.16   9.0  1.10    0.0  13.40  yellow  credit card
#
#              pickup_zone           dropoff_zone pickup_borough  \
# 0        Lenox Hill West    UN/Turtle Bay South      Manhattan
# 1  Upper West Side South  Upper West Side South      Manhattan
# 2          Alphabet City           West Village      Manhattan
# 3              Hudson Sq         Yorkville West      Manhattan
# 4           Midtown East         Yorkville West      Manhattan
#
#   dropoff_borough pickup_dayname  pickup_hour dropoff_dayname  dropoff_hour
# 0       Manhattan       Saturday           20        Saturday            20
# ...

# %%
df.shape
# Out:
# (6341, 16)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
cat=['color','payment','pickup_zone','dropoff_zone','pickup_borough','dropoff_borough','pickup_dayname','dropoff_dayname']
for i in cat:
    df[i]=lb.fit_transform(df[i])

# %%
df.head()
# Out:
#    passengers  distance  fare   tip  tolls  total  color  payment  \
# 0           1      1.60   7.0  2.15    0.0  12.95      1        1
# 1           1      0.79   5.0  0.00    0.0   9.30      1        0
# 2           1      1.37   7.5  2.36    0.0  14.16      1        1
# 3           1      7.70  27.0  6.15    0.0  36.95      1        1
# 4           3      2.16   9.0  1.10    0.0  13.40      1        1
#
#    pickup_zone  dropoff_zone  pickup_borough  dropoff_borough  pickup_dayname  \
# 0           99           176               2                2               2
# 1          174           182               2                2               1
# 2            1           190               2                2               6
# 3           86           202               2                2               3
# 4          116           202               2                2               2
#
#    pickup_hour  dropoff_dayname  dropoff_hour
# 0           20                2            20
# ...

# %%
cont=['fare','tolls','total','distance']

from sklearn.preprocessing import StandardScaler
st=StandardScaler()
df[cont]=st.fit_transform(df[cont])

# %%
df.head()
# Out:
#    passengers  distance      fare   tip     tolls     total  color  payment  \
# 0           1 -0.375780 -0.549175  2.15 -0.229932 -0.413941      1        1
# 1           1 -0.593552 -0.735718  0.00 -0.229932 -0.695808      1        0
# 2           1 -0.437617 -0.502540  2.36 -0.229932 -0.320500      1        1
# 3           1  1.264233  1.316252  6.15 -0.229932  1.439435      1        1
# 4           3 -0.225221 -0.362633  1.10 -0.229932 -0.379190      1        1
#
#    pickup_zone  dropoff_zone  pickup_borough  dropoff_borough  pickup_dayname  \
# 0           99           176               2                2               2
# 1          174           182               2                2               1
# 2            1           190               2                2               6
# 3           86           202               2                2               3
# 4          116           202               2                2               2
#
# ...

# %%
x=df.drop('tip',axis=1)
y=df.tip

# %%
print(x.shape)
print(y.shape)
# Out:
# (6341, 15)
# (6341,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
print('X train shape:',x_train.shape)
print('Y train shape:',y_train.shape)
print('X test shape:',x_test.shape)
print('Y test shape:',y_test.shape)
# Out:
# X train shape: (4755, 15)
# Y train shape: (4755,)
# X test shape: (1586, 15)
# Y test shape: (1586,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-1.21533536e-02,  1.21521094e-01, -7.84096058e+00, -9.61192294e-01,
#         9.65921004e+00, -1.17874988e+00,  5.50080691e-01, -8.52240325e-04,
#        -1.55916239e-03,  2.14444038e-01, -7.22585859e-02,  8.73713085e-03,
#        -1.59562037e-02, -1.46342861e-02, -1.83758010e-03])

# %%
model.intercept_
# Out:
# np.float64(2.8405533370903866)

# %%
y_train_pred=model.predict(x_train)
train_score=model.score(x_train,y_train)
print("Model training score:",train_score)
# Out:
# Model training score: 0.9239021744797632

# %%
y_test_pred=model.predict(x_test)
test_score=model.score(x_test,y_test)
print("Model testing score:",test_score)
# Out:
# Model testing score: 0.9254591746207137

# %%
from sklearn.metrics import root_mean_squared_error,mean_squared_error,mean_absolute_error,r2_score

# %%
root_mean_squared_error(y_train,y_train_pred)
# Out:
# 0.65164113763361

# %%
mean_absolute_error(y_train,y_train_pred)
# Out:
# 0.43814369128765585

# %%
mean_absolute_error(y_train,y_train_pred)
# Out:
# 0.43814369128765585

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.9239021744797632
